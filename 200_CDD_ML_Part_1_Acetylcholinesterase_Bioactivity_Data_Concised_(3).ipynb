# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahfila/My_Coding_Example_DD/blob/main/200_CDD_ML_Part_1_Acetylcholinesterase_Bioactivity_Data_Concised_(3).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Bioinformatics Project - Computational Drug Discovery [Part 1] Download Bioactivity Data (Concised version)**
#
# Chanin Nantasenamat
#
# [*'Data Professor' YouTube channel*](http://youtube.com/dataprofessor)
#
# In this Jupyter notebook, we will be building a real-life **data science project** that you can include in your **data science portfolio**. Particularly, we will be building a machine learning model using the ChEMBL bioactivity data.
#
# In **Part 1**, we will be performing Data Collection and Pre-Processing from the ChEMBL Database.
#
# Note for this Concised Version:
# * Redundant code cells were deleted.
# * Code cells for saving files to Google Drive has been deleted.
#
# ---

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of March 25, 2020; ChEMBL version 26].

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.9-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 703.4 kB/s eta 0:00:00
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (2.0.7)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (2.31.0)
# Collecting requests-cache~=1.2 (from chembl_webresource_client)
#   Downloading requests_cache-1.2.0-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: easydict in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (1.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2024.2.2)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (23.2.0)
# Collecting cattrs>=22.2 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading cattrs-23.2.3-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (4.2.0)
# Collecting url-normalize>=1.4 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Requirement already satisfied: exceptiongroup>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (1.2.0)
# Requirement already satisfied: typing-extensions!=4.6.3,>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (4.11.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from url-normalize>=1.4->requests-cache~=1.2->chembl_webresource_client) (1.16.0)
# Installing collected packages: url-normalize, cattrs, requests-cache, chembl_webresource_client
# Successfully installed cattrs-23.2.3 chembl_webresource_client-0.10.9 requests-cache-1.2.0 url-normalize-1.4.3

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for Acetylcholinesterase**

# %%
# Target search for coronavirus
target = new_client.target
target_query = target.search('corona virus')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                       cross_references  \
# 0                                                   []
# 1                                                   []
# 2    [{'xref_id': 'Thrombopoietin', 'xref_name': No...
# 3                                                   []
# 4                                                   []
# ..                                                 ...
# 196                                                 []
# 197  [{'xref_id': 'Q69422', 'xref_name': None, 'xre...
# 198                                                 []
# 199                                                 []
# 200                                                 []
#
#                                               organism  \
# 0                                         Homo sapiens
# 1                                         Homo sapiens
# 2                                         Homo sapiens
# 3                                         Homo sapiens
# 4                                    Rattus norvegicus
# ..                                                 ...
# 196  Human immunodeficiency virus type 1 (RF/HAT IS...
# 197                               Hepatitis GB virus B
# 198                                       Homo sapiens
# 199                                       Homo sapiens
# 200                                       Homo sapiens
#
#                                              pref_name  score  \
# 0                Hepatitis A virus cellular receptor 2   14.0
# 1             Sodium-dependent phosphate transporter 1   12.0
# 2                                       Thrombopoietin   10.0
# 3                          Transcription factor HIVEP2   10.0
# 4                       G-protein coupled receptor 183   10.0
# ..                                                 ...    ...
# 196  Human immunodeficiency virus type 1 (RF/HAT IS...    4.0
# 197  Hepatitis GB virus B NS5B RNA-dependent RNA po...    4.0
# 198    VEGF-receptor 2 and tyrosine-protein kinase SRC    4.0
# 199                                Sharpin/RBCK1/RNF31    4.0
# 200                                       80S Ribosome    0.0
#
#      species_group_flag target_chembl_id  \
# 0                 False    CHEMBL4630879
# 1                 False    CHEMBL4295909
# 2                 False    CHEMBL1293256
# 3                 False    CHEMBL4523214
# 4                 False    CHEMBL4802001
# ..                  ...              ...
# 196               False     CHEMBL613498
# 197               False       CHEMBL5981
# 198               False    CHEMBL2111336
# 199               False    CHEMBL4296109
# 200               False    CHEMBL3987582
#
#                                      target_components  \
# 0    [{'accession': 'Q8TDQ0', 'component_descriptio...
# 1    [{'accession': 'Q8WUM9', 'component_descriptio...
# 2    [{'accession': 'P40225', 'component_descriptio...
# 3    [{'accession': 'P31629', 'component_descriptio...
# 4    [{'accession': 'D4A7K7', 'component_descriptio...
# ..                                                 ...
# 196                                                 []
# 197  [{'accession': 'Q69422', 'component_descriptio...
# 198  [{'accession': 'P12931', 'component_descriptio...
# 199  [{'accession': 'Q9H0F6', 'component_descriptio...
# 200  [{'accession': 'P08865', 'component_descriptio...
#
#                       target_type  tax_id
# 0                  SINGLE PROTEIN    9606
# 1                  SINGLE PROTEIN    9606
# 2                  SINGLE PROTEIN    9606
# 3                  SINGLE PROTEIN    9606
# 4                  SINGLE PROTEIN   10116
# ..                            ...     ...
# 196                      ORGANISM   11701
# 197                SINGLE PROTEIN   39113
# 198             SELECTIVITY GROUP    9606
# 199               PROTEIN COMPLEX    9606
# 200  PROTEIN NUCLEIC-ACID COMPLEX    9606
#
# [201 rows x 9 columns]

# %% [markdown]
# ### **Select and retrieve bioactivity data for *Human Acetylcholinesterase* (first entry)**

# %% [markdown]
# We will assign the fifth entry (which corresponds to the target protein, *Human Acetylcholinesterase*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[200]
selected_target
# Out:
# 'CHEMBL3987582'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *Human Acetylcholinesterase* (CHEMBL220) that are reported as pChEMBL values.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#    action_type activity_comment  activity_id activity_properties  \
# 0         None             None     12194142                  []
# 1         None             None     12194160                  []
# 2         None             None     12194161                  []
# 3         None             None     12194162                  []
# 4         None             None     12194163                  []
# ..         ...              ...          ...                 ...
# 71        None             None     18944956                  []
# 72        None             None     18944957                  []
# 73        None             None     18944958                  []
# 74        None             None     18944959                  []
# 75        None             None     19164172                  []
#
#    assay_chembl_id                                  assay_description  \
# 0    CHEMBL2214722  Inhibition of mitochondrial ribosome-mediated ...
# 1    CHEMBL2214722  Inhibition of mitochondrial ribosome-mediated ...
# 2    CHEMBL2214722  Inhibition of mitochondrial ribosome-mediated ...
# 3    CHEMBL2214722  Inhibition of mitochondrial ribosome-mediated ...
# 4    CHEMBL2214722  Inhibition of mitochondrial ribosome-mediated ...
# ..             ...                                                ...
# 71   CHEMBL4329571  Binding affinity to 80S ribosome in human HeLa...
# 72   CHEMBL4329571  Binding affinity to 80S ribosome in human HeLa...
# 73   CHEMBL4329571  Binding affinity to 80S ribosome in human HeLa...
# 74   CHEMBL4329571  Binding affinity to 80S ribosome in human HeLa...
# 75   CHEMBL4383960  Binding affinity to 80S ribosome in human HuH7...
#
#    assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0           B                    None                   None  BAO_0000190
# 1           B                    None                   None  BAO_0000190
# 2           B                    None                   None  BAO_0000190
# 3           B                    None                   None  BAO_0000190
# 4           B                    None                   None  BAO_0000190
# ..        ...                     ...                    ...          ...
# 71          B                    None                   None  BAO_0000190
# 72          B                    None                   None  BAO_0000190
# 73          B                    None                   None  BAO_0000190
# 74          B                    None                   None  BAO_0000190
# 75          B                    None                   None  BAO_0000190
#
#     ... target_organism target_pref_name target_tax_id text_value  toid  type  \
# 0   ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 1   ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 2   ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 3   ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 4   ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# ..  ...             ...              ...           ...        ...   ...   ...
# 71  ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 72  ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 73  ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 74  ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 75  ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
#
#    units    uo_units upper_value   value
# 0     uM  UO_0000065        None     7.4
# 1     uM  UO_0000065        None   400.0
# 2     uM  UO_0000065        None   506.0
# 3     uM  UO_0000065        None   681.0
# 4     uM  UO_0000065        None  1493.0
# ..   ...         ...         ...     ...
# 71    uM  UO_0000065        None    3.63
# 72    uM  UO_0000065        None     0.5
# 73    uM  UO_0000065        None    4.38
# 74    uM  UO_0000065        None    0.92
# 75    uM  UO_0000065        None     0.3
#
# [76 rows x 46 columns]

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('acetylcholinesterase_01_bioactivity_data_raw.csv', index=False)

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** and **canonical_smiles** column then drop it.

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
# <ipython-input-61-955aac5800f0>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2 = df2[df.canonical_smiles.notna()]
#    action_type activity_comment  activity_id activity_properties  \
# 0         None             None     12194142                  []
# 1         None             None     12194160                  []
# 2         None             None     12194161                  []
# 3         None             None     12194162                  []
# 4         None             None     12194163                  []
# ..         ...              ...          ...                 ...
# 71        None             None     18944956                  []
# 72        None             None     18944957                  []
# 73        None             None     18944958                  []
# 74        None             None     18944959                  []
# 75        None             None     19164172                  []
#
#    assay_chembl_id                                  assay_description  \
# 0    CHEMBL2214722  Inhibition of mitochondrial ribosome-mediated ...
# 1    CHEMBL2214722  Inhibition of mitochondrial ribosome-mediated ...
# 2    CHEMBL2214722  Inhibition of mitochondrial ribosome-mediated ...
# 3    CHEMBL2214722  Inhibition of mitochondrial ribosome-mediated ...
# 4    CHEMBL2214722  Inhibition of mitochondrial ribosome-mediated ...
# ..             ...                                                ...
# 71   CHEMBL4329571  Binding affinity to 80S ribosome in human HeLa...
# 72   CHEMBL4329571  Binding affinity to 80S ribosome in human HeLa...
# 73   CHEMBL4329571  Binding affinity to 80S ribosome in human HeLa...
# 74   CHEMBL4329571  Binding affinity to 80S ribosome in human HeLa...
# 75   CHEMBL4383960  Binding affinity to 80S ribosome in human HuH7...
#
#    assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0           B                    None                   None  BAO_0000190
# 1           B                    None                   None  BAO_0000190
# 2           B                    None                   None  BAO_0000190
# 3           B                    None                   None  BAO_0000190
# 4           B                    None                   None  BAO_0000190
# ..        ...                     ...                    ...          ...
# 71          B                    None                   None  BAO_0000190
# 72          B                    None                   None  BAO_0000190
# 73          B                    None                   None  BAO_0000190
# 74          B                    None                   None  BAO_0000190
# 75          B                    None                   None  BAO_0000190
#
#     ... target_organism target_pref_name target_tax_id text_value  toid  type  \
# 0   ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 1   ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 2   ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 3   ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 4   ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# ..  ...             ...              ...           ...        ...   ...   ...
# 71  ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 72  ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 73  ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 74  ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 75  ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
#
#    units    uo_units upper_value   value
# 0     uM  UO_0000065        None     7.4
# 1     uM  UO_0000065        None   400.0
# 2     uM  UO_0000065        None   506.0
# 3     uM  UO_0000065        None   681.0
# 4     uM  UO_0000065        None  1493.0
# ..   ...         ...         ...     ...
# 71    uM  UO_0000065        None    3.63
# 72    uM  UO_0000065        None     0.5
# 73    uM  UO_0000065        None    4.38
# 74    uM  UO_0000065        None    0.92
# 75    uM  UO_0000065        None     0.3
#
# [75 rows x 46 columns]

# %%
len(df2.canonical_smiles.unique())
# Out:
# 54

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#    action_type activity_comment  activity_id activity_properties  \
# 0         None             None     12194142                  []
# 1         None             None     12194160                  []
# 2         None             None     12194161                  []
# 3         None             None     12194162                  []
# 4         None             None     12194163                  []
# 5         None             None     12194164                  []
# 6         None             None     12194165                  []
# 7         None             None     12194166                  []
# 8         None             None     12194167                  []
# 9         None             None     12194168                  []
# 10        None             None     12194169                  []
# 11        None             None     12194170                  []
# 12        None             None     12194171                  []
# 13        None             None     12194172                  []
# 15        None             None     12194174                  []
# 16        None             None     15639828                  []
# 17        None             None     15639829                  []
# 18        None             None     15639830                  []
# 19        None             None     15639831                  []
# 20        None             None     15639832                  []
# 21        None             None     15639833                  []
# 22        None             None     15639834                  []
# 23        None             None     15639835                  []
# 24        None             None     15639836                  []
# 25        None             None     15639837                  []
# 26        None             None     15639838                  []
# 27        None             None     15639839                  []
# 28        None             None     15639840                  []
# 29        None             None     18300458                  []
# 30        None             None     18300459                  []
# 31        None             None     18300460                  []
# 32        None             None     18300461                  []
# 33        None             None     18300462                  []
# 34        None             None     18300463                  []
# 35        None             None     18300464                  []
# 36        None             None     18300465                  []
# 37        None             None     18300466                  []
# 38        None             None     18300467                  []
# 39        None             None     18300468                  []
# 51        None             None     18300506                  []
# 52        None             None     18300507                  []
# 53        None             None     18300508                  []
# 57        None             None     18944942                  []
# 58        None             None     18944943                  []
# 59        None             None     18944944                  []
# 60        None             None     18944945                  []
# 61        None             None     18944946                  []
# 62        None             None     18944947                  []
# 63        None             None     18944948                  []
# 64        None             None     18944949                  []
# 71        None             None     18944956                  []
# 72        None             None     18944957                  []
# 73        None             None     18944958                  []
# 74        None             None     18944959                  []
#
#    assay_chembl_id                                  assay_description  \
# 0    CHEMBL2214722  Inhibition of mitochondrial ribosome-mediated ...
# 1    CHEMBL2214722  Inhibition of mitochondrial ribosome-mediated ...
# 2    CHEMBL2214722  Inhibition of mitochondrial ribosome-mediated ...
# 3    CHEMBL2214722  Inhibition of mitochondrial ribosome-mediated ...
# 4    CHEMBL2214722  Inhibition of mitochondrial ribosome-mediated ...
# 5    CHEMBL2214722  Inhibition of mitochondrial ribosome-mediated ...
# 6    CHEMBL2214722  Inhibition of mitochondrial ribosome-mediated ...
# 7    CHEMBL2214722  Inhibition of mitochondrial ribosome-mediated ...
# 8    CHEMBL2214722  Inhibition of mitochondrial ribosome-mediated ...
# 9    CHEMBL2214722  Inhibition of mitochondrial ribosome-mediated ...
# 10   CHEMBL2214722  Inhibition of mitochondrial ribosome-mediated ...
# 11   CHEMBL2214722  Inhibition of mitochondrial ribosome-mediated ...
# 12   CHEMBL2214722  Inhibition of mitochondrial ribosome-mediated ...
# 13   CHEMBL2214722  Inhibition of mitochondrial ribosome-mediated ...
# 15   CHEMBL2214722  Inhibition of mitochondrial ribosome-mediated ...
# 16   CHEMBL3591840  Inhibition of human ribosome containing eukary...
# 17   CHEMBL3591840  Inhibition of human ribosome containing eukary...
# 18   CHEMBL3591840  Inhibition of human ribosome containing eukary...
# 19   CHEMBL3591840  Inhibition of human ribosome containing eukary...
# 20   CHEMBL3591840  Inhibition of human ribosome containing eukary...
# 21   CHEMBL3591840  Inhibition of human ribosome containing eukary...
# 22   CHEMBL3591840  Inhibition of human ribosome containing eukary...
# 23   CHEMBL3591840  Inhibition of human ribosome containing eukary...
# 24   CHEMBL3591840  Inhibition of human ribosome containing eukary...
# 25   CHEMBL3591840  Inhibition of human ribosome containing eukary...
# 26   CHEMBL3591840  Inhibition of human ribosome containing eukary...
# 27   CHEMBL3591840  Inhibition of human ribosome containing eukary...
# 28   CHEMBL3591840  Inhibition of human ribosome containing eukary...
# 29   CHEMBL4124682  Binding affinity to 80S ribosome in human HuH7...
# 30   CHEMBL4124682  Binding affinity to 80S ribosome in human HuH7...
# 31   CHEMBL4124682  Binding affinity to 80S ribosome in human HuH7...
# 32   CHEMBL4124682  Binding affinity to 80S ribosome in human HuH7...
# 33   CHEMBL4124682  Binding affinity to 80S ribosome in human HuH7...
# 34   CHEMBL4124682  Binding affinity to 80S ribosome in human HuH7...
# 35   CHEMBL4124682  Binding affinity to 80S ribosome in human HuH7...
# 36   CHEMBL4124682  Binding affinity to 80S ribosome in human HuH7...
# 37   CHEMBL4124682  Binding affinity to 80S ribosome in human HuH7...
# 38   CHEMBL4124682  Binding affinity to 80S ribosome in human HuH7...
# 39   CHEMBL4124682  Binding affinity to 80S ribosome in human HuH7...
# 51   CHEMBL4124698  Binding affinity to 80S ribosome in human HuH7...
# 52   CHEMBL4124698  Binding affinity to 80S ribosome in human HuH7...
# 53   CHEMBL4124698  Binding affinity to 80S ribosome in human HuH7...
# 57   CHEMBL4329570  Binding affinity to 80S ribosome in human HuH7...
# 58   CHEMBL4329570  Binding affinity to 80S ribosome in human HuH7...
# 59   CHEMBL4329570  Binding affinity to 80S ribosome in human HuH7...
# 60   CHEMBL4329570  Binding affinity to 80S ribosome in human HuH7...
# 61   CHEMBL4329570  Binding affinity to 80S ribosome in human HuH7...
# 62   CHEMBL4329570  Binding affinity to 80S ribosome in human HuH7...
# 63   CHEMBL4329570  Binding affinity to 80S ribosome in human HuH7...
# 64   CHEMBL4329570  Binding affinity to 80S ribosome in human HuH7...
# 71   CHEMBL4329571  Binding affinity to 80S ribosome in human HeLa...
# 72   CHEMBL4329571  Binding affinity to 80S ribosome in human HeLa...
# 73   CHEMBL4329571  Binding affinity to 80S ribosome in human HeLa...
# 74   CHEMBL4329571  Binding affinity to 80S ribosome in human HeLa...
#
#    assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0           B                    None                   None  BAO_0000190
# 1           B                    None                   None  BAO_0000190
# 2           B                    None                   None  BAO_0000190
# 3           B                    None                   None  BAO_0000190
# 4           B                    None                   None  BAO_0000190
# 5           B                    None                   None  BAO_0000190
# 6           B                    None                   None  BAO_0000190
# 7           B                    None                   None  BAO_0000190
# 8           B                    None                   None  BAO_0000190
# 9           B                    None                   None  BAO_0000190
# 10          B                    None                   None  BAO_0000190
# 11          B                    None                   None  BAO_0000190
# 12          B                    None                   None  BAO_0000190
# 13          B                    None                   None  BAO_0000190
# 15          B                    None                   None  BAO_0000190
# 16          B                    None                   None  BAO_0000190
# 17          B                    None                   None  BAO_0000190
# 18          B                    None                   None  BAO_0000190
# 19          B                    None                   None  BAO_0000190
# 20          B                    None                   None  BAO_0000190
# 21          B                    None                   None  BAO_0000190
# 22          B                    None                   None  BAO_0000190
# 23          B                    None                   None  BAO_0000190
# 24          B                    None                   None  BAO_0000190
# 25          B                    None                   None  BAO_0000190
# 26          B                    None                   None  BAO_0000190
# 27          B                    None                   None  BAO_0000190
# 28          B                    None                   None  BAO_0000190
# 29          B                    None                   None  BAO_0000190
# 30          B                    None                   None  BAO_0000190
# 31          B                    None                   None  BAO_0000190
# 32          B                    None                   None  BAO_0000190
# 33          B                    None                   None  BAO_0000190
# 34          B                    None                   None  BAO_0000190
# 35          B                    None                   None  BAO_0000190
# 36          B                    None                   None  BAO_0000190
# 37          B                    None                   None  BAO_0000190
# 38          B                    None                   None  BAO_0000190
# 39          B                    None                   None  BAO_0000190
# 51          B                    None                   None  BAO_0000190
# 52          B                    None                   None  BAO_0000190
# 53          B                    None                   None  BAO_0000190
# 57          B                    None                   None  BAO_0000190
# 58          B                    None                   None  BAO_0000190
# 59          B                    None                   None  BAO_0000190
# 60          B                    None                   None  BAO_0000190
# 61          B                    None                   None  BAO_0000190
# 62          B                    None                   None  BAO_0000190
# 63          B                    None                   None  BAO_0000190
# 64          B                    None                   None  BAO_0000190
# 71          B                    None                   None  BAO_0000190
# 72          B                    None                   None  BAO_0000190
# 73          B                    None                   None  BAO_0000190
# 74          B                    None                   None  BAO_0000190
#
#     ... target_organism target_pref_name target_tax_id text_value  toid  type  \
# 0   ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 1   ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 2   ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 3   ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 4   ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 5   ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 6   ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 7   ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 8   ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 9   ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 10  ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 11  ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 12  ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 13  ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 15  ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 16  ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 17  ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 18  ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 19  ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 20  ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 21  ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 22  ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 23  ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 24  ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 25  ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 26  ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 27  ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 28  ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 29  ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 30  ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 31  ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 32  ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 33  ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 34  ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 35  ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 36  ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 37  ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 38  ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 39  ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 51  ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 52  ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 53  ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 57  ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 58  ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 59  ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 60  ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 61  ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 62  ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 63  ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 64  ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 71  ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 72  ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 73  ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
# 74  ...    Homo sapiens     80S Ribosome          9606       None  None  IC50
#
#       units    uo_units upper_value   value
# 0        uM  UO_0000065        None     7.4
# 1        uM  UO_0000065        None   400.0
# 2        uM  UO_0000065        None   506.0
# 3        uM  UO_0000065        None   681.0
# 4        uM  UO_0000065        None  1493.0
# 5        uM  UO_0000065        None   152.0
# 6        uM  UO_0000065        None   251.0
# 7        uM  UO_0000065        None   710.0
# 8        uM  UO_0000065        None  1408.0
# 9        uM  UO_0000065        None   404.0
# 10       uM  UO_0000065        None   965.0
# 11       uM  UO_0000065        None   492.0
# 12       uM  UO_0000065        None  1785.0
# 13       uM  UO_0000065        None    13.0
# 15       uM  UO_0000065        None    26.0
# 16  ug ml-1  UO_0000274        None   50.54
# 17  ug ml-1  UO_0000274        None   58.03
# 18  ug ml-1  UO_0000274        None   49.85
# 19  ug ml-1  UO_0000274        None  330.74
# 20  ug ml-1  UO_0000274        None    1.86
# 21  ug ml-1  UO_0000274        None   59.12
# 22  ug ml-1  UO_0000274        None    2.19
# 23  ug ml-1  UO_0000274        None    54.6
# 24  ug ml-1  UO_0000274        None    2.23
# 25  ug ml-1  UO_0000274        None  141.35
# 26  ug ml-1  UO_0000274        None    0.34
# 27  ug ml-1  UO_0000274        None    7.62
# 28  ug ml-1  UO_0000274        None   24.11
# 29       uM  UO_0000065        None    2.63
# 30       uM  UO_0000065        None     4.3
# 31       uM  UO_0000065        None    1.06
# 32       uM  UO_0000065        None    0.69
# 33       uM  UO_0000065        None    0.39
# 34       uM  UO_0000065        None    0.38
# 35       uM  UO_0000065        None    0.45
# 36       uM  UO_0000065        None    0.41
# 37       uM  UO_0000065        None    0.71
# 38       uM  UO_0000065        None     4.1
# 39       uM  UO_0000065        None    0.85
# 51       uM  UO_0000065        None    2.97
# 52       uM  UO_0000065        None    2.82
# 53       uM  UO_0000065        None    3.08
# 57       uM  UO_0000065        None    0.38
# 58       uM  UO_0000065        None    0.85
# 59       uM  UO_0000065        None    1.73
# 60       uM  UO_0000065        None    2.21
# 61       uM  UO_0000065        None    2.05
# 62       uM  UO_0000065        None    20.0
# 63       uM  UO_0000065        None    12.6
# 64       uM  UO_0000065        None     3.5
# 71       uM  UO_0000065        None    3.63
# 72       uM  UO_0000065        None     0.5
# 73       uM  UO_0000065        None    4.38
# 74       uM  UO_0000065        None    0.92
#
# [54 rows x 46 columns]

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
#    molecule_chembl_id                                   canonical_smiles  \
# 0       CHEMBL3113999  Nc1cc(S(=O)(=O)N2CCN(c3ccc(C(O)(C(F)(F)F)C(F)(...
# 1       CHEMBL3114190  CC(C)(C)C#CC1CN(S(=O)(=O)c2ccc(N)nc2)CCN1c1ccc...
# 2       CHEMBL3113992  O=S(=O)(c1cccs1)N1CCN(c2ccc(C(O)(C(F)(F)F)C(F)...
# 3       CHEMBL3113993  O=S(=O)(c1ccccc1)N1CCN(c2ccc(C(O)(C(F)(F)F)C(F...
# 4       CHEMBL3114189  Nc1ccc(S(=O)(=O)N2CCN(c3ccc(C(O)(C(F)(F)F)C(F)...
# ..                ...                                                ...
# 88      CHEMBL4549667  CN1C(=O)[C@@H](N2CCc3c(nn(Cc4ccccc4)c3Br)C2=O)...
# 89      CHEMBL4097778  CN1C(=O)[C@@H](N2CCc3cn(CC4CCS(=O)(=O)CC4)nc3C...
# 90      CHEMBL5091943  CCOP(=O)(Cc1csc(NC(=O)c2cc(Oc3ccc(S(C)(=O)=O)c...
# 91      CHEMBL5072532  CCOP(=O)(Cn1ccc(NC(=O)c2cc(Oc3cnc(C(=O)N4CCC4)...
# 92      CHEMBL5181357   O=C1c2ccc(-c3cnc4[nH]ccc4c3)cc2OCCN1Cc1ccc(F)cc1
#
#    standard_value
# 0          8630.0
# 1          1430.0
# 2          1420.0
# 3          1010.0
# 4           779.0
# ..            ...
# 88         1000.0
# 89         1000.0
# 90          122.0
# 91          123.0
# 92         3657.0
#
# [92 rows x 3 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('acetylcholinesterase_02_bioactivity_data_preprocessed.csv', index=False)

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
df4 = pd.read_csv('acetylcholinesterase_02_bioactivity_data_preprocessed.csv')

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#    molecule_chembl_id                                   canonical_smiles  \
# 0       CHEMBL3113999  Nc1cc(S(=O)(=O)N2CCN(c3ccc(C(O)(C(F)(F)F)C(F)(...
# 1       CHEMBL3114190  CC(C)(C)C#CC1CN(S(=O)(=O)c2ccc(N)nc2)CCN1c1ccc...
# 2       CHEMBL3113992  O=S(=O)(c1cccs1)N1CCN(c2ccc(C(O)(C(F)(F)F)C(F)...
# 3       CHEMBL3113993  O=S(=O)(c1ccccc1)N1CCN(c2ccc(C(O)(C(F)(F)F)C(F...
# 4       CHEMBL3114189  Nc1ccc(S(=O)(=O)N2CCN(c3ccc(C(O)(C(F)(F)F)C(F)...
# ..                ...                                                ...
# 87      CHEMBL4549667  CN1C(=O)[C@@H](N2CCc3c(nn(Cc4ccccc4)c3Br)C2=O)...
# 88      CHEMBL4097778  CN1C(=O)[C@@H](N2CCc3cn(CC4CCS(=O)(=O)CC4)nc3C...
# 89      CHEMBL5091943  CCOP(=O)(Cc1csc(NC(=O)c2cc(Oc3ccc(S(C)(=O)=O)c...
# 90      CHEMBL5072532  CCOP(=O)(Cn1ccc(NC(=O)c2cc(Oc3cnc(C(=O)N4CCC4)...
# 91      CHEMBL5181357   O=C1c2ccc(-c3cnc4[nH]ccc4c3)cc2OCCN1Cc1ccc(F)cc1
#
#     standard_value         class
# 0           8630.0  intermediate
# 1           1430.0  intermediate
# 2           1420.0  intermediate
# 3           1010.0  intermediate
# 4            779.0        active
# ..             ...           ...
# 87          1000.0        active
# 88          1000.0        active
# 89           122.0        active
# 90           123.0        active
# 91          3657.0  intermediate
#
# [92 rows x 4 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df5.to_csv('acetylcholinesterase_03_bioactivity_data_curated.csv', index=False)

# %%
! zip acetylcholinesterase.zip *.csv
# Out:
#   adding: acetylcholinesterase_01_bioactivity_data_raw.csv (deflated 90%)
#   adding: acetylcholinesterase_02_bioactivity_data_preprocessed.csv (deflated 82%)
#   adding: acetylcholinesterase_03_bioactivity_data_curated.csv (deflated 83%)

# %%
! ls -l
# Out:
# total 100
# -rw-r--r-- 1 root root 60866 Apr 22 11:42 acetylcholinesterase_01_bioactivity_data_raw.csv
# -rw-r--r-- 1 root root  8417 Apr 22 11:43 acetylcholinesterase_02_bioactivity_data_preprocessed.csv
# -rw-r--r-- 1 root root  9133 Apr 22 11:43 acetylcholinesterase_03_bioactivity_data_curated.csv
# -rw-r--r-- 1 root root  9793 Apr 22 11:43 acetylcholinesterase.zip
# drwxr-xr-x 1 root root  4096 Apr 18 13:25 sample_data

# %% [markdown]
# ---
